# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 766

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config3 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | satka
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | cururupu
# Processing Record 4 of Set 1 | belmonte
# Processing Record 5 of Set 1 | qaqortoq
# Processing Record 6 of Set 1 | shubarkuduk
# Processing Record 7 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 1 | camacha
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | newport
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | placido de castro
# Processing Record 15 of Set 1 | nakusp
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | coro
# Processing Record 19 of Set 1 | sao filipe
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | ler
# Processing Record 24 of Set 1 | shache
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | alta floresta
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | vestmannaeyjar
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | gumdag
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | jinchang
# Processing Record 35 of Set 1 | angola
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | basudebpur
# Processing Record 38 of Set 1 | emerald
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 1 | luis correia
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | ferrol
# Processing Record 47 of Set 1 | las tunas
# Processing Record 48 of Set 1 | castro marim
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | la palma
# Processing Record 1 of Set 2 | chokurdakh
# Processing Record 2 of Set 2 | monrovia
# Processing Record 3 of Set 2 | honiara
# Processing Record 4 of Set 2 | narsaq
# Processing Record 5 of Set 2 | nome
# Processing Record 6 of Set 2 | gamba
# Processing Record 7 of Set 2 | soe
# Processing Record 8 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | husavik
# Processing Record 11 of Set 2 | vilyuysk
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | burnie
# Processing Record 14 of Set 2 | constitucion
# Processing Record 15 of Set 2 | fairbanks
# Processing Record 16 of Set 2 | mayo
# Processing Record 17 of Set 2 | tabuk
# Processing Record 18 of Set 2 | miri
# Processing Record 19 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | shelburne
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | riyadh
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 2 | anito
# Processing Record 27 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 2 | haines junction
# Processing Record 29 of Set 2 | arman
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | tuni
# Processing Record 32 of Set 2 | khirkiya
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | goderich
# Processing Record 35 of Set 2 | hami
# Processing Record 36 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 2 | tuy hoa
# Processing Record 38 of Set 2 | hendek
# Processing Record 39 of Set 2 | vila franca do campo
# Processing Record 40 of Set 2 | klaksvik
# Processing Record 41 of Set 2 | port lincoln
# Processing Record 42 of Set 2 | sechura
# Processing Record 43 of Set 2 | vila velha
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | ust-nera
# Processing Record 47 of Set 2 | huejucar
# Processing Record 48 of Set 2 | ambilobe
# Processing Record 49 of Set 2 | esperance
# Processing Record 50 of Set 2 | barahona
# Processing Record 1 of Set 3 | cherskiy
# Processing Record 2 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 3 | abu dhabi
# Processing Record 4 of Set 3 | takoradi
# Processing Record 5 of Set 3 | vardo
# Processing Record 6 of Set 3 | vanimo
# Processing Record 7 of Set 3 | komsomolskiy
# Processing Record 8 of Set 3 | korla
# Processing Record 9 of Set 3 | brae
# Processing Record 10 of Set 3 | clyde river
# Processing Record 11 of Set 3 | vung tau
# Processing Record 12 of Set 3 | half moon bay
# Processing Record 13 of Set 3 | fortuna
# Processing Record 14 of Set 3 | bambous virieux
# Processing Record 15 of Set 3 | teya
# Processing Record 16 of Set 3 | dunkirk
# Processing Record 17 of Set 3 | igarka
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | nicoya
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | haverfordwest
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | ambunti
# Processing Record 25 of Set 3 | traverse city
# Processing Record 26 of Set 3 | baloda
# Processing Record 27 of Set 3 | umm lajj
# Processing Record 28 of Set 3 | thompson
# Processing Record 29 of Set 3 | campestre
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | belaya gora
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | port blair
# Processing Record 35 of Set 3 | pirawa
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | gornopravdinsk
# Processing Record 38 of Set 3 | nantucket
# Processing Record 39 of Set 3 | belyy
# Processing Record 40 of Set 3 | ilulissat
# Processing Record 41 of Set 3 | upernavik
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | katsuura
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | kunigal
# Processing Record 46 of Set 3 | broken hill
# Processing Record 47 of Set 3 | kamenka
# Processing Record 48 of Set 3 | bethel
# Processing Record 49 of Set 3 | sosua
# Processing Record 50 of Set 3 | seoul
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | ocean city
# Processing Record 3 of Set 4 | gladstone
# Processing Record 4 of Set 4 | tuktoyaktuk
# Processing Record 5 of Set 4 | lebu
# Processing Record 6 of Set 4 | broome
# Processing Record 7 of Set 4 | port alfred
# Processing Record 8 of Set 4 | abapo
# Processing Record 9 of Set 4 | arlit
# Processing Record 10 of Set 4 | port hardy
# Processing Record 11 of Set 4 | dingzhou
# Processing Record 12 of Set 4 | port keats
# Processing Record 13 of Set 4 | kahului
# Processing Record 14 of Set 4 | gumla
# Processing Record 15 of Set 4 | kaohsiung
# Processing Record 16 of Set 4 | torbay
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | jiangyou
# Processing Record 19 of Set 4 | touros
# Processing Record 20 of Set 4 | acarau
# Processing Record 21 of Set 4 | celestun
# Processing Record 22 of Set 4 | qaanaaq
# Processing Record 23 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 4 | fasa
# Processing Record 25 of Set 4 | conde
# Processing Record 26 of Set 4 | busko-zdroj
# Processing Record 27 of Set 4 | padang
# Processing Record 28 of Set 4 | marang
# Processing Record 29 of Set 4 | tuatapere
# Processing Record 30 of Set 4 | aklavik
# Processing Record 31 of Set 4 | alofi
# Processing Record 32 of Set 4 | santa rosa
# Processing Record 33 of Set 4 | kenai
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | libreville
# Processing Record 36 of Set 4 | usinsk
# Processing Record 37 of Set 4 | shingu
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | sur
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | atuona
# Processing Record 42 of Set 4 | yulara
# Processing Record 43 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 4 | sawtell
# Processing Record 45 of Set 4 | koundara
# Processing Record 46 of Set 4 | saldanha
# Processing Record 47 of Set 4 | putina
# Processing Record 48 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 4 | dubti
# Processing Record 50 of Set 4 | brenham
# Processing Record 1 of Set 5 | leshukonskoye
# Processing Record 2 of Set 5 | piranshahr
# Processing Record 3 of Set 5 | walvis bay
# Processing Record 4 of Set 5 | madras
# Processing Record 5 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 5 | petropavlivka
# Processing Record 7 of Set 5 | nedjo
# Processing Record 8 of Set 5 | labuhan
# Processing Record 9 of Set 5 | lumphat
# Processing Record 10 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 5 | lamu
# Processing Record 12 of Set 5 | ugoofaaru
# Processing Record 13 of Set 5 | sambava
# Processing Record 14 of Set 5 | chifeng
# Processing Record 15 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 5 | zhovtneve
# Processing Record 17 of Set 5 | manicore
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | lemesos
# City not found. Skipping...
# Processing Record 20 of Set 5 | puerto ayora
# Processing Record 21 of Set 5 | chapais
# Processing Record 22 of Set 5 | pevek
# Processing Record 23 of Set 5 | sorong
# Processing Record 24 of Set 5 | salta
# Processing Record 25 of Set 5 | carnarvon
# Processing Record 26 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 5 | cabo san lucas
# Processing Record 28 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 5 | lima
# Processing Record 30 of Set 5 | guayaramerin
# Processing Record 31 of Set 5 | pawa
# Processing Record 32 of Set 5 | moose factory
# Processing Record 33 of Set 5 | northam
# Processing Record 34 of Set 5 | oistins
# Processing Record 35 of Set 5 | inongo
# Processing Record 36 of Set 5 | saint-cyr-sur-loire
# Processing Record 37 of Set 5 | sitka
# Processing Record 38 of Set 5 | puerto leguizamo
# Processing Record 39 of Set 5 | fort nelson
# Processing Record 40 of Set 5 | ostrovnoy
# Processing Record 41 of Set 5 | zunyi
# Processing Record 42 of Set 5 | east london
# Processing Record 43 of Set 5 | guerrero negro
# Processing Record 44 of Set 5 | alenquer
# Processing Record 45 of Set 5 | kodinsk
# Processing Record 46 of Set 5 | tamandare
# Processing Record 47 of Set 5 | ayan
# Processing Record 48 of Set 5 | mantua
# Processing Record 49 of Set 5 | horki
# Processing Record 50 of Set 5 | cockburn town
# Processing Record 1 of Set 6 | sisimiut
# Processing Record 2 of Set 6 | imbituba
# Processing Record 3 of Set 6 | naze
# Processing Record 4 of Set 6 | bonoua
# Processing Record 5 of Set 6 | kashiwazaki
# Processing Record 6 of Set 6 | straseni
# Processing Record 7 of Set 6 | kpandae
# Processing Record 8 of Set 6 | barranca
# Processing Record 9 of Set 6 | chuy
# Processing Record 10 of Set 6 | nefteyugansk
# Processing Record 11 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 6 | krasnyy chikoy
# Processing Record 13 of Set 6 | tucuman
# Processing Record 14 of Set 6 | hope
# Processing Record 15 of Set 6 | ballina
# Processing Record 16 of Set 6 | tessalit
# Processing Record 17 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 6 | lofthus
# Processing Record 19 of Set 6 | neman
# Processing Record 20 of Set 6 | tura
# Processing Record 21 of Set 6 | severo-kurilsk
# Processing Record 22 of Set 6 | pocone
# Processing Record 23 of Set 6 | scarborough
# Processing Record 24 of Set 6 | zeya
# Processing Record 25 of Set 6 | bosaso
# Processing Record 26 of Set 6 | faanui
# Processing Record 27 of Set 6 | penzance
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | egvekinot
# Processing Record 30 of Set 6 | salekhard
# Processing Record 31 of Set 6 | sao joao da barra
# Processing Record 32 of Set 6 | ponta do sol
# Processing Record 33 of Set 6 | eston
# Processing Record 34 of Set 6 | inta
# Processing Record 35 of Set 6 | bandar
# Processing Record 36 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 6 | gizo
# Processing Record 38 of Set 6 | saint-georges
# Processing Record 39 of Set 6 | krasnyy profintern
# Processing Record 40 of Set 6 | cedar city
# Processing Record 41 of Set 6 | mount pleasant
# Processing Record 42 of Set 6 | kita
# Processing Record 43 of Set 6 | ngaoundere
# Processing Record 44 of Set 6 | tiksi
# Processing Record 45 of Set 6 | madera
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | san patricio
# Processing Record 48 of Set 6 | aasiaat
# Processing Record 49 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 6 | joao pinheiro
# Processing Record 1 of Set 7 | paytug
# City not found. Skipping...
# Processing Record 2 of Set 7 | jackson
# Processing Record 3 of Set 7 | pueblo nuevo
# Processing Record 4 of Set 7 | sibu
# Processing Record 5 of Set 7 | kavaratti
# Processing Record 6 of Set 7 | grajau
# Processing Record 7 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 7 | nouadhibou
# Processing Record 9 of Set 7 | maarianhamina
# Processing Record 10 of Set 7 | poum
# Processing Record 11 of Set 7 | acajutla
# Processing Record 12 of Set 7 | bathsheba
# Processing Record 13 of Set 7 | marsa matruh
# Processing Record 14 of Set 7 | mandan
# Processing Record 15 of Set 7 | notodden
# Processing Record 16 of Set 7 | airai
# Processing Record 17 of Set 7 | maroantsetra
# Processing Record 18 of Set 7 | isabela
# Processing Record 19 of Set 7 | kodiak
# Processing Record 20 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | kidal
# Processing Record 23 of Set 7 | marzuq
# Processing Record 24 of Set 7 | escarcega
# Processing Record 25 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 7 | marawi
# Processing Record 27 of Set 7 | datong
# Processing Record 28 of Set 7 | japura
# Processing Record 29 of Set 7 | kristinehamn
# Processing Record 30 of Set 7 | champerico
# Processing Record 31 of Set 7 | pak phanang
# Processing Record 32 of Set 7 | talara
# Processing Record 33 of Set 7 | okato
# Processing Record 34 of Set 7 | beisfjord
# Processing Record 35 of Set 7 | aykhal
# Processing Record 36 of Set 7 | adrar
# Processing Record 37 of Set 7 | lebedinyy
# Processing Record 38 of Set 7 | portland
# Processing Record 39 of Set 7 | buala
# Processing Record 40 of Set 7 | saint-augustin
# Processing Record 41 of Set 7 | hermosillo
# Processing Record 42 of Set 7 | pokhara
# Processing Record 43 of Set 7 | dyersburg
# Processing Record 44 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 45 of Set 7 | san policarpo
# Processing Record 46 of Set 7 | tautira
# Processing Record 47 of Set 7 | mana
# Processing Record 48 of Set 7 | hegang
# Processing Record 49 of Set 7 | kismayo
# Processing Record 50 of Set 7 | whitecourt
# Processing Record 1 of Set 8 | neosho
# Processing Record 2 of Set 8 | lahad datu
# Processing Record 3 of Set 8 | parit buntar
# Processing Record 4 of Set 8 | yabelo
# Processing Record 5 of Set 8 | morondava
# Processing Record 6 of Set 8 | norman wells
# Processing Record 7 of Set 8 | zelenoborskiy
# Processing Record 8 of Set 8 | tilichiki
# Processing Record 9 of Set 8 | gainesville
# Processing Record 10 of Set 8 | surgut
# Processing Record 11 of Set 8 | auki
# Processing Record 12 of Set 8 | caravelas
# Processing Record 13 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 14 of Set 8 | whitehorse
# Processing Record 15 of Set 8 | iqaluit
# Processing Record 16 of Set 8 | tharad
# Processing Record 17 of Set 8 | ewa beach
# Processing Record 18 of Set 8 | lafiagi
# Processing Record 19 of Set 8 | luderitz
# Processing Record 20 of Set 8 | lenki
# City not found. Skipping...
# Processing Record 21 of Set 8 | hammerfest
# Processing Record 22 of Set 8 | dhanera
# Processing Record 23 of Set 8 | kilgore
# Processing Record 24 of Set 8 | hundorp
# Processing Record 25 of Set 8 | sinnamary
# Processing Record 26 of Set 8 | tsaratanana
# Processing Record 27 of Set 8 | bhubaneswar
# Processing Record 28 of Set 8 | teacapan
# Processing Record 29 of Set 8 | botwood
# Processing Record 30 of Set 8 | sola
# Processing Record 31 of Set 8 | tongren
# Processing Record 32 of Set 8 | tadine
# Processing Record 33 of Set 8 | kloulklubed
# Processing Record 34 of Set 8 | leningradskiy
# Processing Record 35 of Set 8 | altea
# Processing Record 36 of Set 8 | lagoa
# Processing Record 37 of Set 8 | coihaique
# Processing Record 38 of Set 8 | dukat
# Processing Record 39 of Set 8 | pisco
# Processing Record 40 of Set 8 | lesozavodsk
# Processing Record 41 of Set 8 | ternate
# Processing Record 42 of Set 8 | severo-yeniseyskiy
# Processing Record 43 of Set 8 | okitipupa
# Processing Record 44 of Set 8 | malanje
# Processing Record 45 of Set 8 | paris
# Processing Record 46 of Set 8 | cefalu
# Processing Record 47 of Set 8 | marrakesh
# Processing Record 48 of Set 8 | alekseyevsk
# Processing Record 49 of Set 8 | kavieng
# Processing Record 50 of Set 8 | havelock
# Processing Record 1 of Set 9 | markova
# Processing Record 2 of Set 9 | mpika
# Processing Record 3 of Set 9 | batticaloa
# Processing Record 4 of Set 9 | nishihara
# Processing Record 5 of Set 9 | hithadhoo
# Processing Record 6 of Set 9 | taree
# Processing Record 7 of Set 9 | piterka
# Processing Record 8 of Set 9 | cervo
# Processing Record 9 of Set 9 | blenheim
# Processing Record 10 of Set 9 | staryy nadym
# Processing Record 11 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 12 of Set 9 | pangnirtung
# Processing Record 13 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 14 of Set 9 | bellevue
# Processing Record 15 of Set 9 | atar
# Processing Record 16 of Set 9 | oktyabrskoye
# Processing Record 17 of Set 9 | alice springs
# Processing Record 18 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 19 of Set 9 | kurilsk
# Processing Record 20 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 9 | san cristobal
# Processing Record 22 of Set 9 | hofn
# Processing Record 23 of Set 9 | araouane
# Processing Record 24 of Set 9 | sarangani
# Processing Record 25 of Set 9 | urengoy
# Processing Record 26 of Set 9 | bustonkala
# City not found. Skipping...
# Processing Record 27 of Set 9 | bonthe
# Processing Record 28 of Set 9 | mehamn
# Processing Record 29 of Set 9 | kasama
# Processing Record 30 of Set 9 | isangel
# Processing Record 31 of Set 9 | presidencia roque saenz pena
# Processing Record 32 of Set 9 | leh
# Processing Record 33 of Set 9 | gewane
# Processing Record 34 of Set 9 | angoram
# Processing Record 35 of Set 9 | hasaki
# Processing Record 36 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 9 | nushki
# Processing Record 38 of Set 9 | dubbo
# Processing Record 39 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 9 | inuvik
# Processing Record 41 of Set 9 | ignacio zaragoza
# Processing Record 42 of Set 9 | pastavy
# Processing Record 43 of Set 9 | kutum
# Processing Record 44 of Set 9 | goldap
# Processing Record 45 of Set 9 | galveston
# Processing Record 46 of Set 9 | yatou
# Processing Record 47 of Set 9 | khasan
# Processing Record 48 of Set 9 | brive-la-gaillarde
# Processing Record 49 of Set 9 | iberia
# Processing Record 50 of Set 9 | kirkuk
# Processing Record 1 of Set 10 | talaya
# Processing Record 2 of Set 10 | sandwick
# Processing Record 3 of Set 10 | marmande
# Processing Record 4 of Set 10 | hambantota
# Processing Record 5 of Set 10 | haslett
# Processing Record 6 of Set 10 | ilam
# Processing Record 7 of Set 10 | mareeba
# Processing Record 8 of Set 10 | lompoc
# Processing Record 9 of Set 10 | sjoholt
# Processing Record 10 of Set 10 | teguise
# Processing Record 11 of Set 10 | ciudad bolivar
# Processing Record 12 of Set 10 | juazeirinho
# Processing Record 13 of Set 10 | freeport
# Processing Record 14 of Set 10 | erenhot
# Processing Record 15 of Set 10 | namibe
# Processing Record 16 of Set 10 | brantford
# Processing Record 17 of Set 10 | faya
# Processing Record 18 of Set 10 | libertador general san martin
# Processing Record 19 of Set 10 | saint pete beach
# Processing Record 20 of Set 10 | marienburg
# Processing Record 21 of Set 10 | balkhash
# Processing Record 22 of Set 10 | savalia
# Processing Record 23 of Set 10 | kedrovyy
# Processing Record 24 of Set 10 | sorrento
# Processing Record 25 of Set 10 | tamworth
# Processing Record 26 of Set 10 | wajima
# Processing Record 27 of Set 10 | jumla
# Processing Record 28 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 10 | san rafael
# Processing Record 30 of Set 10 | karabulak
# Processing Record 31 of Set 10 | doha
# Processing Record 32 of Set 10 | darnah
# Processing Record 33 of Set 10 | kerema
# Processing Record 34 of Set 10 | berlevag
# Processing Record 35 of Set 10 | sangar
# Processing Record 36 of Set 10 | isetskoye
# Processing Record 37 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 38 of Set 10 | henties bay
# Processing Record 39 of Set 10 | la ronge
# Processing Record 40 of Set 10 | kemin
# Processing Record 41 of Set 10 | ibra
# Processing Record 42 of Set 10 | porto novo
# Processing Record 43 of Set 10 | wegorzewo
# Processing Record 44 of Set 10 | poya
# Processing Record 45 of Set 10 | porbandar
# Processing Record 46 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 10 | kangaatsiaq
# Processing Record 48 of Set 10 | eureka
# Processing Record 49 of Set 10 | pangai
# Processing Record 50 of Set 10 | santa maria
# Processing Record 1 of Set 11 | grand gaube
# Processing Record 2 of Set 11 | port hawkesbury
# Processing Record 3 of Set 11 | linxia
# Processing Record 4 of Set 11 | korocha
# Processing Record 5 of Set 11 | bandarbeyla
# Processing Record 6 of Set 11 | wewak
# Processing Record 7 of Set 11 | nuuk
# Processing Record 8 of Set 11 | tartki
# City not found. Skipping...
# Processing Record 9 of Set 11 | hokitika
# Processing Record 10 of Set 11 | yar-sale
# Processing Record 11 of Set 11 | mount gambier
# Processing Record 12 of Set 11 | svetlogorsk
# Processing Record 13 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 11 | andenes
# Processing Record 15 of Set 11 | kargasok
# Processing Record 16 of Set 11 | mackay
# Processing Record 17 of Set 11 | prince albert
# Processing Record 18 of Set 11 | hobyo
# Processing Record 19 of Set 11 | nichinan
# Processing Record 20 of Set 11 | port augusta
# Processing Record 21 of Set 11 | conceicao da barra
# Processing Record 22 of Set 11 | magadan
# Processing Record 23 of Set 11 | dunedin
# Processing Record 24 of Set 11 | artyshta
# Processing Record 25 of Set 11 | mpongwe
# Processing Record 26 of Set 11 | lagos
# Processing Record 27 of Set 11 | zyryanka
# Processing Record 28 of Set 11 | horodnytsya
# Processing Record 29 of Set 11 | karatau
# Processing Record 30 of Set 11 | storforshei
# Processing Record 31 of Set 11 | lavrentiya
# Processing Record 32 of Set 11 | victoria
# Processing Record 33 of Set 11 | polunochnoye
# Processing Record 34 of Set 11 | obigarm
# Processing Record 35 of Set 11 | ahipara
# Processing Record 36 of Set 11 | gubkinskiy
# Processing Record 37 of Set 11 | wapi pathum
# Processing Record 38 of Set 11 | liverpool
# Processing Record 39 of Set 11 | severnoye
# Processing Record 40 of Set 11 | brookhaven
# Processing Record 41 of Set 11 | aktash
# Processing Record 42 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 43 of Set 11 | sao jose da coroa grande
# Processing Record 44 of Set 11 | illapel
# Processing Record 45 of Set 11 | alyangula
# Processing Record 46 of Set 11 | birao
# Processing Record 47 of Set 11 | quatre cocos
# Processing Record 48 of Set 11 | pacific grove
# Processing Record 49 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 11 | sabang
# Processing Record 1 of Set 12 | manavalakurichi
# Processing Record 2 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 3 of Set 12 | trelew
# Processing Record 4 of Set 12 | shenjiamen
# Processing Record 5 of Set 12 | anton lizardo
# Processing Record 6 of Set 12 | avera
# Processing Record 7 of Set 12 | beyneu
# Processing Record 8 of Set 12 | da nang
# Processing Record 9 of Set 12 | karratha
# Processing Record 10 of Set 12 | te anau
# Processing Record 11 of Set 12 | kurumkan
# Processing Record 12 of Set 12 | kasangulu
# Processing Record 13 of Set 12 | berbera
# Processing Record 14 of Set 12 | aksu
# Processing Record 15 of Set 12 | lasa
# Processing Record 16 of Set 12 | san giorgio ionico
# Processing Record 17 of Set 12 | sorland
# Processing Record 18 of Set 12 | shar
# Processing Record 19 of Set 12 | marsh harbour
# Processing Record 20 of Set 12 | adolfo lopez mateos
# Processing Record 21 of Set 12 | anqing
# Processing Record 22 of Set 12 | terra roxa
# Processing Record 23 of Set 12 | zaton
# Processing Record 24 of Set 12 | chateaubelair
# Processing Record 25 of Set 12 | iskateley
# Processing Record 26 of Set 12 | lubao
# Processing Record 27 of Set 12 | hualmay
# Processing Record 28 of Set 12 | trairi
# Processing Record 29 of Set 12 | rudnogorsk
# Processing Record 30 of Set 12 | meadow lake
# Processing Record 31 of Set 12 | foshan
# Processing Record 32 of Set 12 | voi
# Processing Record 33 of Set 12 | solnechnyy
# Processing Record 34 of Set 12 | kapiri mposhi
# Processing Record 35 of Set 12 | sept-iles
# Processing Record 36 of Set 12 | namtsy
# Processing Record 37 of Set 12 | salalah
# Processing Record 38 of Set 12 | trincomalee
# Processing Record 39 of Set 12 | krasnoarmeysk
# Processing Record 40 of Set 12 | ahuimanu
# Processing Record 41 of Set 12 | kiruna
# Processing Record 42 of Set 12 | zhanakorgan
# Processing Record 43 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 12 | virginia beach
# Processing Record 45 of Set 12 | tual
# Processing Record 46 of Set 12 | aliaga
# Processing Record 47 of Set 12 | noyabrsk
# Processing Record 48 of Set 12 | rorvik
# Processing Record 49 of Set 12 | havre
# Processing Record 50 of Set 12 | novoagansk
# Processing Record 1 of Set 13 | kieta
# Processing Record 2 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 3 of Set 13 | shu
# Processing Record 4 of Set 13 | manono
# Processing Record 5 of Set 13 | palmas bellas
# Processing Record 6 of Set 13 | rosetta
# Processing Record 7 of Set 13 | lata
# Processing Record 8 of Set 13 | santa isabel do rio negro
# Processing Record 9 of Set 13 | muzhi
# Processing Record 10 of Set 13 | taganak
# Processing Record 11 of Set 13 | aleksandrovsk-sakhalinskiy
# Processing Record 12 of Set 13 | merauke
# Processing Record 13 of Set 13 | qingyuan
# Processing Record 14 of Set 13 | boulsa
# Processing Record 15 of Set 13 | poddorye
# Processing Record 16 of Set 13 | muisne
# Processing Record 17 of Set 13 | taoudenni
# Processing Record 18 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 19 of Set 13 | knysna
# Processing Record 20 of Set 13 | bajil
# Processing Record 21 of Set 13 | hanna
# Processing Record 22 of Set 13 | aqtobe
# Processing Record 23 of Set 13 | north bend
# Processing Record 24 of Set 13 | shaunavon
# Processing Record 25 of Set 13 | along
# Processing Record 26 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 13 | sungai petani
# Processing Record 28 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 13 | yining
# Processing Record 30 of Set 13 | mitsamiouli
# Processing Record 31 of Set 13 | yian
# City not found. Skipping...
# Processing Record 32 of Set 13 | batagay
# Processing Record 33 of Set 13 | flinders
# Processing Record 34 of Set 13 | marystown
# Processing Record 35 of Set 13 | tezu
# Processing Record 36 of Set 13 | fiumicino
# Processing Record 37 of Set 13 | erzin
# Processing Record 38 of Set 13 | souillac
# Processing Record 39 of Set 13 | mayya
# Processing Record 40 of Set 13 | xinqing
# Processing Record 41 of Set 13 | nanortalik
# Processing Record 42 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 43 of Set 13 | mapastepec
# Processing Record 44 of Set 13 | makubetsu
# Processing Record 45 of Set 13 | aktau
# Processing Record 46 of Set 13 | dzhubga
# Processing Record 47 of Set 13 | salinas
# Processing Record 48 of Set 13 | genc
# Processing Record 49 of Set 13 | harper
# Processing Record 50 of Set 13 | khandyga
# Processing Record 1 of Set 14 | el alto
# Processing Record 2 of Set 14 | nyurba
# Processing Record 3 of Set 14 | gigmoto
# Processing Record 4 of Set 14 | mbandaka
# Processing Record 5 of Set 14 | tocopilla
# Processing Record 6 of Set 14 | chipinge
# Processing Record 7 of Set 14 | pochutla
# Processing Record 8 of Set 14 | xucheng
# Processing Record 9 of Set 14 | yumen
# Processing Record 10 of Set 14 | abu samrah
# Processing Record 11 of Set 14 | bonavista
# Processing Record 12 of Set 14 | malakal
# Processing Record 13 of Set 14 | barra patuca
# Processing Record 14 of Set 14 | amuntai
# Processing Record 15 of Set 14 | akdepe
# Processing Record 16 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 14 | kaeo
# Processing Record 18 of Set 14 | teknaf
# Processing Record 19 of Set 14 | san jeronimo
# Processing Record 20 of Set 14 | cayambe
# Processing Record 21 of Set 14 | gorontalo
# Processing Record 22 of Set 14 | college
# Processing Record 23 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 14 | general pico
# Processing Record 25 of Set 14 | serra
# Processing Record 26 of Set 14 | suna
# Processing Record 27 of Set 14 | ponca city
# Processing Record 28 of Set 14 | sturgeon bay
# Processing Record 29 of Set 14 | taunggyi
# Processing Record 30 of Set 14 | manokwari
# Processing Record 31 of Set 14 | palana
# Processing Record 32 of Set 14 | midyat
# Processing Record 33 of Set 14 | krabi
# Processing Record 34 of Set 14 | do gonbadan
# Processing Record 35 of Set 14 | wuwei
# Processing Record 36 of Set 14 | maldonado
# Processing Record 37 of Set 14 | paamiut
# Processing Record 38 of Set 14 | olafsvik
# Processing Record 39 of Set 14 | banda aceh
# Processing Record 40 of Set 14 | acapulco
# Processing Record 41 of Set 14 | severnyy
# Processing Record 42 of Set 14 | nipawin
# Processing Record 43 of Set 14 | ntchisi
# Processing Record 44 of Set 14 | san quintin
# Processing Record 45 of Set 14 | kandrian
# Processing Record 46 of Set 14 | diffa
# Processing Record 47 of Set 14 | westport
# Processing Record 48 of Set 14 | bac lieu
# Processing Record 49 of Set 14 | iralaya
# Processing Record 50 of Set 14 | shchuchye
# City not found. Skipping...
# Processing Record 1 of Set 15 | san martin
# Processing Record 2 of Set 15 | kuching
# Processing Record 3 of Set 15 | makueni
# Processing Record 4 of Set 15 | nelson bay
# Processing Record 5 of Set 15 | gimli
# Processing Record 6 of Set 15 | moengo
# Processing Record 7 of Set 15 | zhigansk
# Processing Record 8 of Set 15 | palmer
# Processing Record 9 of Set 15 | redmond
# Processing Record 10 of Set 15 | spencer
# Processing Record 11 of Set 15 | yurimaguas
# Processing Record 12 of Set 15 | hirara
# Processing Record 13 of Set 15 | toora-khem
# Processing Record 14 of Set 15 | fayaoue
# Processing Record 15 of Set 15 | ambo
# Processing Record 16 of Set 15 | ribnitz-damgarten
# Processing Record 17 of Set 15 | durgapur
# Processing Record 18 of Set 15 | morros
# Processing Record 19 of Set 15 | aswan
# Processing Record 20 of Set 15 | kupang
# Processing Record 21 of Set 15 | mayumba
# Processing Record 22 of Set 15 | akyab
# Processing Record 23 of Set 15 | emilio carranza
# Processing Record 24 of Set 15 | areosa
# Processing Record 25 of Set 15 | samarinda
# Processing Record 26 of Set 15 | hamina
# Processing Record 27 of Set 15 | binzhou
# Processing Record 28 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 15 | tete
# Processing Record 30 of Set 15 | yanam
# Processing Record 31 of Set 15 | mao
# Processing Record 32 of Set 15 | pervomayskiy
# Processing Record 33 of Set 15 | anloga
# Processing Record 34 of Set 15 | hailey
# Processing Record 35 of Set 15 | muriti
# Processing Record 36 of Set 15 | namatanai
# Processing Record 37 of Set 15 | awjilah
# Processing Record 38 of Set 15 | umm kaddadah
# Processing Record 39 of Set 15 | keti bandar
# Processing Record 40 of Set 15 | mandalgovi
# Processing Record 41 of Set 15 | lithakia
# Processing Record 42 of Set 15 | beringovskiy
# Processing Record 43 of Set 15 | rosita
# Processing Record 44 of Set 15 | reconquista
# Processing Record 45 of Set 15 | aranos
# Processing Record 46 of Set 15 | ndioum
# Processing Record 47 of Set 15 | port macquarie
# Processing Record 48 of Set 15 | ipoti
# Processing Record 49 of Set 15 | farafangana
# Processing Record 50 of Set 15 | umea
# Processing Record 1 of Set 16 | bilma
# Processing Record 2 of Set 16 | evensk
# Processing Record 3 of Set 16 | nordby
# Processing Record 4 of Set 16 | roma
# Processing Record 5 of Set 16 | amzya
# Processing Record 6 of Set 16 | otane
# Processing Record 7 of Set 16 | waipawa
# Processing Record 8 of Set 16 | khandbari
# Processing Record 9 of Set 16 | mogadishu
# Processing Record 10 of Set 16 | chernyshevskiy
# Processing Record 11 of Set 16 | kabanga
# Processing Record 12 of Set 16 | sant feliu de guixols
# Processing Record 13 of Set 16 | praia da vitoria
# Processing Record 14 of Set 16 | koppal
# Processing Record 15 of Set 16 | elko
# Processing Record 16 of Set 16 | menongue
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0           Satka  55.0425   59.0400     33.60     overcast clouds        84
# 1    Punta Arenas -53.1500  -70.9167     50.11       broken clouds        57
# 2        Cururupu  -1.8283  -44.8683     83.43          few clouds        66
# 3        Belmonte -15.8631  -38.8828     77.50       broken clouds        81
# 4        Qaqortoq  60.7167  -46.0333     43.30           clear sky        47
# 5     Shubarkuduk  49.1447   56.4872     51.84     overcast clouds        63
# 6         Camacha  33.0833  -16.3333     69.22          few clouds        73
# 7  Port Elizabeth -33.9180   25.5701     63.10           clear sky        86
# 8          Hobart -42.8794  147.3294     45.10    scattered clouds        87
# 9         Newport  51.5877   -2.9984     56.86          light rain        88
#
#    Cloudiness  Wind Speed Country
# 0         100       13.62      RU
# 1          75       33.38      CL
# 2          19        5.93      BR
# 3          81        9.71      BR
# 4           0        0.78      GL
# 5          99        6.85      KZ
# 6          20        4.61      PT
# 7           9       14.38      ZA
# 8          40        8.05      AU
# 9           7       14.94      GB

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Satka      RU  55.0425   59.0400     33.60        84         100
# 1    Punta Arenas      CL -53.1500  -70.9167     50.11        57          75
# 2        Cururupu      BR  -1.8283  -44.8683     83.43        66          19
# 3        Belmonte      BR -15.8631  -38.8828     77.50        81          81
# 4        Qaqortoq      GL  60.7167  -46.0333     43.30        47           0
# 5     Shubarkuduk      KZ  49.1447   56.4872     51.84        63          99
# 6         Camacha      PT  33.0833  -16.3333     69.22        73          20
# 7  Port Elizabeth      ZA -33.9180   25.5701     63.10        86           9
# 8          Hobart      AU -42.8794  147.3294     45.10        87          40
# 9         Newport      GB  51.5877   -2.9984     56.86        88           7
#
#    Wind Speed Current Description
# 0       13.62     overcast clouds
# 1       33.38       broken clouds
# 2        5.93          few clouds
# 3        9.71       broken clouds
# 4        0.78           clear sky
# 5        6.85     overcast clouds
# 6        4.61          few clouds
# 7       14.38           clear sky
# 8        8.05    scattered clouds
# 9       14.94          light rain

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
